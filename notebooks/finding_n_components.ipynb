# %% [markdown]
# # Find optimal number of components for PCA
# Plot explained variance and assess elbow for optimal number of components.
# Uncomment the line `plt.savefig('pca_explained_variance.png')` to save the plot.

# %%
from sklearn.decomposition import PCA

# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

d = np.load("../data/nonsynchr_casevectors.npy")  # shape: 68687, 300

# %%
# Get number of components for 99% variance.
pca99 = PCA(n_components=0.99, svd_solver="full").fit(d)
pca99.components_.shape
# Out:
# (277, 300)

# %%
# Get number of components for 95% variance.
pca95 = PCA(n_components=0.95).fit(d)
pca95.components_.shape
# Out:
# (215, 300)

# %%
# Plot cumulative explained variance.
pca = PCA().fit(d)
plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.xlabel("number of components")
plt.ylabel("cumulative explained variance")
# plt.savefig("../../figures/PCA_variance.png")
# Out:
# Text(0, 0.5, 'cumulative explained variance')
